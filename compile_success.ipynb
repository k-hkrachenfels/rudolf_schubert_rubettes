# %% [markdown]
# <a href="https://colab.research.google.com/github/k-hkrachenfels/rudolf_schubert_rubettes/blob/main/compile_success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://xxx:x-oauth-basic@github.com/k-hkrachenfels/rubettes.git
# Out:
# Cloning into 'rubettes'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 0), reused 9 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), 165.15 KiB | 7.18 MiB/s, done.

# %%
ls rubettes
# Out:
# gema.txt  platte01  platte01.c  readme.md  rubettes.txt  universal_music.txt

# %%
# !wget ftp://ftp.gnu.org/gnu/gsl/gsl-2.6.tar.gz
# Out:
# --2023-03-15 11:53:08--  ftp://ftp.gnu.org/gnu/gsl/gsl-2.6.tar.gz
#            => ‘gsl-2.6.tar.gz’
# Resolving ftp.gnu.org (ftp.gnu.org)... 209.51.188.20, 2001:470:142:3::b
# Connecting to ftp.gnu.org (ftp.gnu.org)|209.51.188.20|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gnu/gsl ... done.
# ==> SIZE gsl-2.6.tar.gz ... 7398548
# ==> PASV ... done.    ==> RETR gsl-2.6.tar.gz ... done.
# Length: 7398548 (7.1M) (unauthoritative)
#
# gsl-2.6.tar.gz      100%[===================>]   7.06M  23.7MB/s    in 0.3s
#
# 2023-03-15 11:53:09 (23.7 MB/s) - ‘gsl-2.6.tar.gz’ saved [7398548]

# %%
# !tar -zxvf gsl-2.6.tar.gz

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir gsl

# %%
# !cd gsl-2.6 && ./configure --prefix=/content/gsl

# %%
# !cd gsl-2.6 && make
# Out:
# make  all-recursive
# make[1]: Entering directory '/content/gsl-2.6'
# Making all in gsl
# make[2]: Entering directory '/content/gsl-2.6/gsl'
# rm -f gsl*.h
# HEADERLIST="../gsl*.h ../*/gsl*.h"; \
# for h in $HEADERLIST; do \
#   BASENAME=`basename $h`; \
#   test -r $BASENAME || ln -s $h $BASENAME; \
# done
# make[2]: Leaving directory '/content/gsl-2.6/gsl'
# Making all in utils
# make[2]: Entering directory '/content/gsl-2.6/utils'
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..     -g -O2 -MT placeholder.lo -MD -MP -MF .deps/placeholder.Tpo -c -o placeholder.lo placeholder.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -g -O2 -MT placeholder.lo -MD -MP -MF .deps/placeholder.Tpo -c placeholder.c  -fPIC -DPIC -o .libs/placeholder.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -g -O2 -MT placeholder.lo -MD -MP -MF .deps/placeholder.Tpo -c placeholder.c -o placeholder.o >/dev/null 2>&1
# mv -f .deps/placeholder.Tpo .deps/placeholder.Plo
# ...

# %%
# !cd gsl-2.6 && make check
# Out:
# Making check in gsl
# make[1]: Entering directory '/content/gsl-2.6/gsl'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/content/gsl-2.6/gsl'
# Making check in utils
# make[1]: Entering directory '/content/gsl-2.6/utils'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/content/gsl-2.6/utils'
# Making check in sys
# make[1]: Entering directory '/content/gsl-2.6/sys'
# make  test
# make[2]: Entering directory '/content/gsl-2.6/sys'
# gcc -DHAVE_CONFIG_H -I. -I..  -I..   -g -O2 -MT test.o -MD -MP -MF .deps/test.Tpo -c -o test.o test.c
# mv -f .deps/test.Tpo .deps/test.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -g -O2   -o test test.o libgslsys.la ../ieee-utils/libgslieeeutils.la ../err/libgslerr.la ../test/libgsltest.la libgslsys.la ../utils/libutils.la -lm
# ...

# %%
# !cd gsl-2.6 && make install
# Out:
# Making install in gsl
# make[1]: Entering directory '/content/gsl-2.6/gsl'
# make[2]: Entering directory '/content/gsl-2.6/gsl'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/content/gsl-2.6/gsl'
# make[1]: Leaving directory '/content/gsl-2.6/gsl'
# Making install in utils
# make[1]: Entering directory '/content/gsl-2.6/utils'
# make[2]: Entering directory '/content/gsl-2.6/utils'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/content/gsl-2.6/utils'
# make[1]: Leaving directory '/content/gsl-2.6/utils'
# Making install in sys
# make[1]: Entering directory '/content/gsl-2.6/sys'
# make[2]: Entering directory '/content/gsl-2.6/sys'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/content/gsl/include/gsl'
#  /usr/bin/install -c -m 644 gsl_sys.h '/content/gsl/include/gsl'
# ...

# %% [markdown]
# ## Mit 2.6 über das tar installiert geht es:

# %%
# !cd rubettes && gcc -I/content/gsl/include -L/content/gsl/lib platte01.c -o platte01 -lgsl -lpthread -lgslcblas -lm

# %% [markdown]
# ## ubuntu package mit v 2.5 geht nicht:
# **Text fett markieren**

# %%
# !sudo apt-get update -y

# %%
# !apt-get install -y libgsl-dev

# %%
# !cd rubettes && cc -o platte01 platte01.c -lgsl -lcblas -lm -Wall -O3 
#-lgsl -lgslcblas -lm -L/usr/local/lib

# %%
# !apt-cache policy libgsl-dev

# %%
# !apt-get update && apt-get install -y libgsl-dev
